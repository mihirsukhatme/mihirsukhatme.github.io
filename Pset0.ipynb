# %% [markdown]
# <a href="https://colab.research.google.com/github/mihirsukhatme/mihirsukhatme.github.io/blob/main/Pset0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PSet 0
# Due February 12, 2026 11:59 PM
#
# This PSet will give you an opportunity to practice assorted operations in PyTorch and BioPython that will be useful for future work in this course.

# %% [markdown]
# # Basic Problems
#
# Before completing this section, familiarize yourself with PyTorch at:
# https://pytorch.org/tutorials/beginner/basics/intro.html

# %%
import torch

# %% [markdown]
# ## 1. Tensor Creation and Properties
# **Question 1a** Create a 1-dimensional tensor of size 8 filled with ones.
#
# **Question 1b** Create a 2-dimensional tensor of size 3x3 filled with random numbers.
#
# **Question 1c** Write a function that takes a tensor and prints its shape, datatype, and the device it is on.

# %%
#Your code here

# %% [markdown]
# ## 2. Indexing and Slicing:
#
# **Question 2a** Create a 2-dimensional tensor of shape (6, 6) with random integers between 0 and 20. Extract the middle 4x4 matrix.
#
# **Question 2b** Extract the diagonal elements of the above-created matrix.

# %%
#Your code here

# %% [markdown]
# ## 3. Basic Operations:
#
# **Question 3a** Create two tensors of size (4, 4) with random integers. Add, subtract, and multiply them element-wise.
#
# **Question 3b** Compute the matrix multiplication of two matrices of size (3, 4) and (4, 6).

# %%
#Your code here

# %% [markdown]
# # Intermediate Problems

# %% [markdown]
# ## 4. Dimensional Operations
#
# **Question 4a** Create a tensor of shape (4, 7) and compute the sum along the first dimension.
#
# **Question 4b** Now compute the sum along the second dimension.
#
# **Question 4c** Create a 3-dimensional tensor of shape (3, 4, 5). Transpose the tensor to shape (5, 4, 3).

# %%
#Your code here

# %% [markdown]
# ## 5. Reshaping
#
# **Question 5a** Create a tensor of random numbers with shape (8, 2). Reshape it to (4, 4).
#
# **Question 5b** Consider a tensor t of shape (64,). Reshape it to a shape of (8, 8) and then to (2, 16, 2).

# %%
#Your code here

# %% [markdown]
# ## 6. Broadcasting
#
# **Question 6a** Create a tensor of shape (4, 4) and a tensor of shape (4, 1). Perform element-wise addition to see how broadcasting works.
#
# **Question 6b** Explain what happens when you try to add tensors of shape (5, 1, 4) and (3, 1).
#
# **Question 6c** Create a tensor of shape (5, 1, 4) and a tensor of shape (3, 1) and perform element-wise subtraction. ~Explain how the broadcasting process is applied to these two tensors.~ This should demonstrate your explaination in **6b**.

# %%
#Your code here

# %% [markdown]
# # Advanced Problems

# %% [markdown]
# ## 7. Advanced Indexing
#
# **Question 7a** Create a tensor of shape (12, 12) with random integers. Set the values in the range [3, 9) in the 5th row to zero using boolean indexing.
#
# **Question 7b** Select the elements in a (6, 6) matrix that are in the odd rows and even columns.

# %%
#Your code here

# %% [markdown]
# ## 8. Batch Matrix Operations
#
# **Question 8a** Create a batch of matrices of shape (8, 3, 3). Compute the determinant of each 3x3 matrix. Hint: see [torch.linalg.det](https://pytorch.org/docs/stable/generated/torch.linalg.det.html).
#
# **Question 8b** Create two batches of matrices A and B of shapes (8, 3, 4) and (8, 4, 5) respectively. Perform batch matrix multiplication.

# %%
#Your code here

# %% [markdown]
# ## 9. Advanced Operations and Functions
#
# **Question 9a** Create a tensor ```t``` of shape (100,) filled with random integers. Find the mean, the standard deviation, and the median of ```t```.
#
# **Question 9b** Use the ```torch.where``` function to replace all negative values in a tensor of shape (5, 5) with the value 0.
#
# **Question 9c** Create two tensors with the same shape and filled with random integers. Use ```torch.where``` to find the element-wise minimum of the two tensors.

# %%
#Your code here

# %% [markdown]
# ## 10. Gradients and Differentiation
#
# **Question 10a** Create two tensors x and y of size 5, with ```requires_grad=True```. Compute an expression (e.g., $z = x * x + y * y$) and then calculate the gradient of z with respect to x and y.
#
# **Question 10b** Reset the gradient of x and y, and recompute z without autograd.

# %%
#Your code here

# %% [markdown]
# # BioPython
#
# Before starting this section, familiarize yourself with the basics of Biopython at:
# https://biopython.org/DIST/docs/tutorial/Tutorial.html
#
# **Notes for Solving the Problems**
#
# You may need to refer to the Biopython documentation or specific modules like SeqIO for sequence input/output, Seq for sequence objects, Entrez for fetching data from NCBI, and Align for sequence alignments.
#
# Ensure that you handle file paths correctly when reading from or writing to files.
# Some problems require an internet connection, as they involve fetching data from NCBI.
# Solving these problems will provide a solid foundation in handling biological data and performing basic bioinformatics tasks using Biopython.

# %% [markdown]
# ## 11. Create and Manipulate Sequences
#
#
# **Question 11a** Create a DNA sequence object for the following sequence: "ATGCGTACGTTAGCC".
#
# **Question 11b** Print out the length of the sequence.
#
# **Question 11c** Compute the GC content of the sequence.
#
# **Question 11d** Print the reverse complement of the sequence.

# %%
#Your code here

# %% [markdown]
# ## 12. Transcription and Translation
#
# **Question 12a** Transcribe the DNA sequence from above into mRNA.
#
# **Question 12b** Translate the mRNA sequence into an amino acid sequence.
#
# **Question 12c** Print the original DNA sequence, the transcribed mRNA sequence, and the translated amino acid sequence.

# %%
#Your code here

# %% [markdown]
# ## 13. Sequence IO
#
# **Question 13a** Read a [FASTA file](https://drive.google.com/file/d/1Eo1mV8T82XNWEC8Jnn4QB18mq2KH_HBH/view?usp=sharing) and print the IDs and sequences.
#
# **Question 13b** Write the sequences to a new FASTA file, but with all the sequences converted to their reverse complements.

# %%
#Your code here

# %% [markdown]
# ##14. Fetching Data from NCBI
#
# **Question 14a** Use the Entrez module to search for and download nucleotide sequence data for the following gene accession number: **NM_001200025**.
# **Question 14b** Parse the downloaded data and print the description and sequence.

# %%
#Your code here

# %% [markdown]
# ##15. Sequence Alignment
#
# **Question 15a** Perform a pairwise alignment between the following two sequences:
#  - Sequence 1: "ACTGCTAGCTAG"
#  - Sequence 2: "GCTAGCTGATCG"
#
# **Quesiton 15b** Print the alignments and the alignment score.

# %%
#Your code here

# %% [markdown]
# ## 16. Bioinformatics Data Structures
#
# **Question 16a** Load a [GenBank file](https://drive.google.com/file/d/10UIFRwCU_YWhvTzZ9CXGEcn5VMNDBhUf/view?usp=sharing).
#
# **Question 16b** Extract all features of type "gene" and print their locations and associated gene names.
#
# **Question 16c** Modify one of the gene annotations and write the modified record to a new file.

# %%
#Your code here
